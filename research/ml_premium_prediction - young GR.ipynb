# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from sklearn.linear_model import LinearRegression, ridge_regression

from xgboost import XGBRegressor

# %% [markdown]
# <h2 align="center" style="color:Green">Data Loading</h2>

# %%
df = pd.read_excel(r"D:\AI-engineer Study\Projects\Project 7 Premium Prediction ver1\data\premiums_young_with_gr.xlsx")
df.head()
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   18    Male  Northeast      Unmarried                     0   Overweight
# 1   22  Female  Northwest      Unmarried                     0  Underweight
# 2   21  Female  Southeast      Unmarried                     0       Normal
# 3   25    Male  Southeast      Unmarried                     0       Normal
# 4   20    Male  Southeast      Unmarried                     2   Overweight
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0        Regular     Self-Employed        > 40L            99
# 1     No Smoking        Freelancer         <10L             3
# 2        Regular          Salaried        > 40L            97
# 3     No Smoking        Freelancer    10L - 25L            15
# 4     No Smoking        Freelancer    10L - 25L            14
#
#        Medical History Insurance_Plan  Annual_Premium_Amount  Genetical_Risk
# 0  High blood pressure         Silver                  13365               4
# 1           No Disease         Silver                  11050               3
# 2           No Disease         Silver                  11857               4
# 3           No Disease         Bronze                   5684               2
# 4           No Disease         Bronze                   5712               1

# %%
df.shape
# Out:
# (20096, 14)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Region', 'Marital_status', 'Number Of Dependants',
#        'BMI_Category', 'Smoking_Status', 'Employment_Status', 'Income_Level',
#        'Income_Lakhs', 'Medical History', 'Insurance_Plan',
#        'Annual_Premium_Amount', 'Genetical_Risk'],
#       dtype='str')

# %%
df.columns.str.replace(" ", "_").str.lower()
# Out:
# Index(['age', 'gender', 'region', 'marital_status', 'number_of_dependants',
#        'bmi_category', 'smoking_status', 'employment_status', 'income_level',
#        'income_lakhs', 'medical_history', 'insurance_plan',
#        'annual_premium_amount', 'genetical_risk'],
#       dtype='str')

# %%
df.columns = df.columns.str.replace(" ", "_").str.lower()

# %%
df.columns
# Out:
# Index(['age', 'gender', 'region', 'marital_status', 'number_of_dependants',
#        'bmi_category', 'smoking_status', 'employment_status', 'income_level',
#        'income_lakhs', 'medical_history', 'insurance_plan',
#        'annual_premium_amount', 'genetical_risk'],
#       dtype='str')

# %% [markdown]
# <h2 align="center" style="color:green">Exploratory Data Analysis & Data Cleaning</h2>

# %% [markdown]
# ### Handle missing values

# %%
df.isnull().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           2
# employment_status        1
# income_level             4
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# genetical_risk           0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           0
# employment_status        0
# income_level             0
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# genetical_risk           0
# dtype: int64

# %% [markdown]
# ### Handle duplicate

# %%
if df.duplicated().sum() > 0:
    print(f"Before drop duplicate: {df.duplicated().sum()}")
    df.drop_duplicates(inplace=True)
    print(f"After drop duplicate: {df.duplicated().sum()}")
else:
    print(f"No duplicate: {df.duplicated().sum()}")
# Out:
# No duplicate: 0

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  20090.000000          20090.000000  20090.000000
# mean      21.494375              0.718019     22.510851
# std        2.294052              0.940713     23.420493
# min       18.000000             -3.000000      1.000000
# 25%       19.000000              0.000000      6.000000
# 50%       22.000000              0.000000     16.000000
# 75%       23.000000              1.000000     31.000000
# max       25.000000              3.000000    790.000000
#
#        annual_premium_amount  genetical_risk
# count           20090.000000    20090.000000
# mean             8142.096267        2.503932
# std              2749.906347        1.710203
# min              3501.000000        0.000000
# 25%              6022.250000        1.000000
# 50%              7939.000000        3.000000
# 75%              9561.000000        4.000000
# max             18186.000000        5.000000

# %% [markdown]
# #### Data Cleaning: number_of_dependants

# %%
df.loc[df['number_of_dependants'] < 0]['number_of_dependants'].unique()
# Out:
# array([-3, -1])

# %% [markdown]
# We can see some negative values in number_of_dependants. We can replace them with positive numbers

# %%
df['number_of_dependants'] = np.abs(df['number_of_dependants'])

# %%
df.loc[df['number_of_dependants'] < 0]['number_of_dependants'].unique()
# Out:
# array([], dtype=int64)

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  20090.000000          20090.000000  20090.000000
# mean      21.494375              0.722598     22.510851
# std        2.294052              0.937200     23.420493
# min       18.000000              0.000000      1.000000
# 25%       19.000000              0.000000      6.000000
# 50%       22.000000              0.000000     16.000000
# 75%       23.000000              1.000000     31.000000
# max       25.000000              3.000000    790.000000
#
#        annual_premium_amount  genetical_risk
# count           20090.000000    20090.000000
# mean             8142.096267        2.503932
# std              2749.906347        1.710203
# min              3501.000000        0.000000
# 25%              6022.250000        1.000000
# 50%              7939.000000        3.000000
# 75%              9561.000000        4.000000
# max             18186.000000        5.000000

# %% [markdown]
# ## 1. Numeric Columns
# ### Univariate Analysis: Numeric Columns
# #### Box plots for numeric columns

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'income_lakhs', 'annual_premium_amount',
#        'genetical_risk'],
#       dtype='str')

# %%
for col in numeric_columns:
    sns.boxplot(data=df, y=col)
    plt.title(f"Box plot of {col}")
    plt.show()

# %% [markdown]
# ### Outlier Treatment: Age Column

# %%
df.loc[df['age'] > 100]['age'].unique()
# Out:
# array([], dtype=int64)

# %%
df.loc[df['age'] > 100].shape[0]
# Out:
# 0

# %%
df1 = df.loc[df['age'] <= 100]
df1.shape[0]
# Out:
# 20090

# %%
df1.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  20090.000000          20090.000000  20090.000000
# mean      21.494375              0.722598     22.510851
# std        2.294052              0.937200     23.420493
# min       18.000000              0.000000      1.000000
# 25%       19.000000              0.000000      6.000000
# 50%       22.000000              0.000000     16.000000
# 75%       23.000000              1.000000     31.000000
# max       25.000000              3.000000    790.000000
#
#        annual_premium_amount  genetical_risk
# count           20090.000000    20090.000000
# mean             8142.096267        2.503932
# std              2749.906347        1.710203
# min              3501.000000        0.000000
# 25%              6022.250000        1.000000
# 50%              7939.000000        3.000000
# 75%              9561.000000        4.000000
# max             18186.000000        5.000000

# %% [markdown]
# ### Outlier Treatment: Income Column

# %%
def get_iqr_bound(col):
    q1, q3 = col.quantile([0.25, 0.75])
    IQR = q3 - q1
    upper_bound = q3 + (1.5 * IQR)
    lower_bound = q1 - (1.5 * IQR)
    return lower_bound, upper_bound

lower, upper = get_iqr_bound(df1['income_lakhs'])
lower, upper
# Out:
# (-31.5, 68.5)

# %%
df1.loc[df1['income_lakhs'] > upper].shape[0]
# Out:
# 1295

# %% [markdown]
# There are many legitimate records that we will get rid of if we use IQR bounds method. Hence after discussion with business we decided to use a simple quantile bound

# %%
quantile_thresold = df1['income_lakhs'].quantile(0.999)
quantile_thresold
# Out:
# np.float64(100.0)

# %%
df1.loc[df1['income_lakhs'] > quantile_thresold].shape[0]
# Out:
# 4

# %%
df2 = df1.loc[df1['income_lakhs'] <= quantile_thresold].copy()
df2.shape
# Out:
# (20086, 14)

# %%
df2.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  20086.000000          20086.000000  20086.000000
# mean      21.494474              0.722742     22.390371
# std        2.294248              0.937238     21.732062
# min       18.000000              0.000000      1.000000
# 25%       19.000000              0.000000      6.000000
# 50%       22.000000              0.000000     16.000000
# 75%       23.000000              1.000000     31.000000
# max       25.000000              3.000000    100.000000
#
#        annual_premium_amount  genetical_risk
# count           20086.000000    20086.000000
# mean             8141.799263        2.503883
# std              2749.912486        1.710184
# min              3501.000000        0.000000
# 25%              6022.000000        1.000000
# 50%              7939.000000        3.000000
# 75%              9561.000000        4.000000
# max             18186.000000        5.000000

# %%
import math

# 1. Determine grid dimensions dynamically
ncols = 2
nrows = math.ceil(len(numeric_columns) / ncols)

fig, axs = plt.subplots(nrows=nrows, ncols=ncols, figsize=(10, 4 * nrows))

# 2. Flatten axs to a 1D array for simple 1D indexing
axs = axs.ravel()

# 3. Plot each numeric column
for i, column in enumerate(numeric_columns):
    sns.histplot(df2[column], kde=True, ax=axs[i])
    axs[i].set_title(column)

# 4. Hide empty subplots if numeric_columns is an odd count
for j in range(len(numeric_columns), len(axs)):
    fig.delaxes(axs[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate Analysis: Numeric Columns

# %%
numeric_features = ['age', 'income_lakhs', 'number_of_dependants']

fig, axes = plt.subplots(1, len(numeric_features), figsize=(18, 6))  # Adjust figure size as necessary

for ax, column in zip(axes, numeric_features):
    sns.scatterplot(x=df2[column], y=df2['annual_premium_amount'], ax=ax)
    ax.set_title(f'{column} vs. Annual Premium Amount')
    ax.set_xlabel(column)
    ax.set_ylabel('Annual Premium Amount')

plt.tight_layout()  # Adjust layout
plt.show()

# %%
categorical_cols = df.select_dtypes(include=['str']).columns
print(categorical_cols)
len(categorical_cols)
# Out:
# Index(['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status',
#        'employment_status', 'income_level', 'medical_history',
#        'insurance_plan'],
#       dtype='str')
# 9

# %%
for col in categorical_cols:
    print(col, ": ", df2[col].unique())
# Out:
# gender :  <ArrowStringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
# region :  <ArrowStringArray>
# ['Northeast', 'Northwest', 'Southeast', 'Southwest']
# Length: 4, dtype: str
# marital_status :  <ArrowStringArray>
# ['Unmarried', 'Married']
# Length: 2, dtype: str
# bmi_category :  <ArrowStringArray>
# ['Overweight', 'Underweight', 'Normal', 'Obesity']
# Length: 4, dtype: str
# smoking_status :  <ArrowStringArray>
# [       'Regular',     'No Smoking',     'Occasional',      'Smoking=0',
#  'Does Not Smoke',    'Not Smoking']
# Length: 6, dtype: str
# employment_status :  <ArrowStringArray>
# ['Self-Employed', 'Freelancer', 'Salaried']
# Length: 3, dtype: str
# income_level :  <ArrowStringArray>
# ['> 40L', '<10L', '10L - 25L', '25L - 40L']
# Length: 4, dtype: str
# medical_history :  <ArrowStringArray>
# [                'High blood pressure',                          'No Disease',
#       'Diabetes & High blood pressure',            'Diabetes & Heart disease',
#                             'Diabetes',                  'Diabetes & Thyroid',
#                        'Heart disease',                             'Thyroid',
#  'High blood pressure & Heart disease']
# Length: 9, dtype: str
# insurance_plan :  <ArrowStringArray>
# ['Silver', 'Bronze', 'Gold']
# Length: 3, dtype: str

# %%
df2.replace({'smoking_status':{
        'Not Smoking': 'No Smoking',
        'Does Not Smoke': 'No Smoking',
        'Smoking=0': 'No Smoking'
}}, inplace=True)

df2['smoking_status'].unique()
# Out:
# <ArrowStringArray>
# ['Regular', 'No Smoking', 'Occasional']
# Length: 3, dtype: str

# %% [markdown]
# ### Univariate Analysis

# %%
df2.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   18    Male  Northeast      Unmarried                     0   Overweight
# 1   22  Female  Northwest      Unmarried                     0  Underweight
# 2   21  Female  Southeast      Unmarried                     0       Normal
# 3   25    Male  Southeast      Unmarried                     0       Normal
# 4   20    Male  Southeast      Unmarried                     2   Overweight
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0        Regular     Self-Employed        > 40L            99
# 1     No Smoking        Freelancer         <10L             3
# 2        Regular          Salaried        > 40L            97
# 3     No Smoking        Freelancer    10L - 25L            15
# 4     No Smoking        Freelancer    10L - 25L            14
#
#        medical_history insurance_plan  annual_premium_amount  genetical_risk
# 0  High blood pressure         Silver                  13365               4
# 1           No Disease         Silver                  11050               3
# 2           No Disease         Silver                  11857               4
# 3           No Disease         Bronze                   5684               2
# 4           No Disease         Bronze                   5712               1

# %%
pct_count = df2['gender'].value_counts(normalize=True)*100
pct_count
# Out:
# gender
# Male      55.038335
# Female    44.961665
# Name: proportion, dtype: float64

# %%
sns.barplot(x=pct_count.index, y=pct_count.values)
plt.show()

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 18))  # Adjust figure size as necessary
axes = axes.flatten()  # Flatten the 2D array of axes into 1D for easier iteration

for ax, column in zip(axes, categorical_cols):
    # Calculate the percentage distribution of each category
    category_counts = df2[column].value_counts(normalize=True) * 100  # normalize=True gives the relative frequencies
    
    # Plotting the distribution using barplot
    sns.barplot(x=category_counts.index, y=category_counts.values, ax=ax)
    ax.set_title(f'Percentage Distribution of {column}')
    ax.set_ylabel('Percentage of Policyholders (%)')
    ax.set_xlabel(column)  # Set xlabel to the column name for clarity

plt.tight_layout()  # Adjusts plot parameters for better fit in the figure window
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
crosstab = pd.crosstab(df2['income_level'], df2['insurance_plan'])
print(crosstab)

# Plotting the crosstab
crosstab.plot(kind='bar', stacked=True)
plt.title('Income vs Plan')
plt.ylabel('Count')
plt.show()
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L         4508   326     828
# 25L - 40L         3382   209     608
# <10L              6172   404    1145
# > 40L              115   366    2023

# %%
sns.heatmap(crosstab, annot=True, cmap='coolwarm',fmt="d")
plt.title('Heatmap of Income vs Plan')
plt.show()

# %% [markdown]
# <h2 align="center" style="color:green">Feature Engineering</h2>

# %%
df2.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   18    Male  Northeast      Unmarried                     0   Overweight
# 1   22  Female  Northwest      Unmarried                     0  Underweight
# 2   21  Female  Southeast      Unmarried                     0       Normal
# 3   25    Male  Southeast      Unmarried                     0       Normal
# 4   20    Male  Southeast      Unmarried                     2   Overweight
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0        Regular     Self-Employed        > 40L            99
# 1     No Smoking        Freelancer         <10L             3
# 2        Regular          Salaried        > 40L            97
# 3     No Smoking        Freelancer    10L - 25L            15
# 4     No Smoking        Freelancer    10L - 25L            14
#
#        medical_history insurance_plan  annual_premium_amount  genetical_risk
# 0  High blood pressure         Silver                  13365               4
# 1           No Disease         Silver                  11050               3
# 2           No Disease         Silver                  11857               4
# 3           No Disease         Bronze                   5684               2
# 4           No Disease         Bronze                   5712               1

# %%
risk_scores = {
    "diabetes": 6,
    "heart disease": 8,
    "high blood pressure":6,
    "thyroid": 5,
    "no disease": 0,
    "none":0
}

# %%
df2['medical_history'].str.split(" & ", expand=True).apply(lambda x: x.str.lower())
# Out:
#                          0    1
# 0      high blood pressure  NaN
# 1               no disease  NaN
# 2               no disease  NaN
# 3               no disease  NaN
# 4               no disease  NaN
# ...                    ...  ...
# 20091           no disease  NaN
# 20092             diabetes  NaN
# 20093           no disease  NaN
# 20094           no disease  NaN
# 20095           no disease  NaN
#
# [20086 rows x 2 columns]

# %% [markdown]
# ### Split medical_history into 'disease1', 'disease2'

# %%
df2[['disease1', 'disease2']] = df2['medical_history'].str.split(" & ", expand=True).apply(lambda x: x.str.lower())
df2[['disease1', 'disease2']].sample(5)
# Out:
#          disease1 disease2
# 3065   no disease      NaN
# 9424   no disease      NaN
# 3695   no disease      NaN
# 18383  no disease      NaN
# 7639     diabetes      NaN

# %%
# df2['disease1'].fillna("", inplace=True)
# df2['disease2'].fillna("", inplace=True)

df2.fillna({"disease1": "none"}, inplace=True)
df2.fillna({"disease2": "none"}, inplace=True)
df2[['disease1', 'disease2']].sample(5)
# Out:
#          disease1 disease2
# 14461  no disease     none
# 14630  no disease     none
# 12352  no disease     none
# 15848  no disease     none
# 4475   no disease     none

# %%
df2.head(3)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   18    Male  Northeast      Unmarried                     0   Overweight
# 1   22  Female  Northwest      Unmarried                     0  Underweight
# 2   21  Female  Southeast      Unmarried                     0       Normal
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0        Regular     Self-Employed        > 40L            99
# 1     No Smoking        Freelancer         <10L             3
# 2        Regular          Salaried        > 40L            97
#
#        medical_history insurance_plan  annual_premium_amount  genetical_risk  \
# 0  High blood pressure         Silver                  13365               4
# 1           No Disease         Silver                  11050               3
# 2           No Disease         Silver                  11857               4
#
#               disease1 disease2
# 0  high blood pressure     none
# 1           no disease     none
# 2           no disease     none

# %% [markdown]
# ### Adding column total_risk_score

# %%
df2['total_risk_score'] = 0

# %%
for disease in ['disease1', 'disease2']:
    df2['total_risk_score'] += df2[disease].map(risk_scores)

# %%
df2.sample(5)
# Out:
#        age  gender     region marital_status  number_of_dependants  \
# 9375    25  Female  Southeast      Unmarried                     1
# 11269   19    Male  Northeast      Unmarried                     2
# 1260    22    Male  Northwest        Married                     2
# 9838    22  Female  Southwest      Unmarried                     1
# 17464   18    Male  Southwest      Unmarried                     1
#
#       bmi_category smoking_status employment_status income_level  \
# 9375   Underweight     No Smoking        Freelancer        > 40L
# 11269       Normal     No Smoking          Salaried    10L - 25L
# 1260        Normal     No Smoking        Freelancer    25L - 40L
# 9838   Underweight     No Smoking        Freelancer    10L - 25L
# 17464       Normal        Regular     Self-Employed        > 40L
#
#        income_lakhs      medical_history insurance_plan  \
# 9375             93  High blood pressure         Silver
# 11269            17  High blood pressure         Bronze
# 1260             40             Diabetes         Silver
# 9838             14           No Disease         Bronze
# 17464            79           No Disease         Silver
#
#        annual_premium_amount  genetical_risk             disease1 disease2  \
# 9375                   11744               4  high blood pressure     none
# 11269                   6866               2  high blood pressure     none
# 1260                   12696               5             diabetes     none
# 9838                    8042               4           no disease     none
# 17464                  13276               5           no disease     none
#
#        total_risk_score
# 9375                  6
# 11269                 6
# 1260                  6
# 9838                  0
# 17464                 0

# %%
df2.shape
# Out:
# (20086, 17)

# %%
df3 = df2.drop(columns=['medical_history', 'disease1', 'disease2'])
df3.head()
df3.shape
# Out:
# (20086, 14)

# %%
X = df3.drop(columns=['annual_premium_amount'])
y = df3['annual_premium_amount']

# %%
X.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   18    Male  Northeast      Unmarried                     0   Overweight
# 1   22  Female  Northwest      Unmarried                     0  Underweight
# 2   21  Female  Southeast      Unmarried                     0       Normal
# 3   25    Male  Southeast      Unmarried                     0       Normal
# 4   20    Male  Southeast      Unmarried                     2   Overweight
#
#   smoking_status employment_status income_level  income_lakhs insurance_plan  \
# 0        Regular     Self-Employed        > 40L            99         Silver
# 1     No Smoking        Freelancer         <10L             3         Silver
# 2        Regular          Salaried        > 40L            97         Silver
# 3     No Smoking        Freelancer    10L - 25L            15         Bronze
# 4     No Smoking        Freelancer    10L - 25L            14         Bronze
#
#    genetical_risk  total_risk_score
# 0               4                 6
# 1               3                 0
# 2               4                 0
# 3               2                 0
# 4               1                 0

# %%
y.head()
# Out:
# 0    13365
# 1    11050
# 2    11857
# 3     5684
# 4     5712
# Name: annual_premium_amount, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline

# 1. Feature groupings
nominal_cols = [
    'gender', 'region', 'marital_status', 
    'bmi_category', 'smoking_status', 'employment_status'
]

# Raw numeric columns (do not include raw string columns here)
numeric_cols = ['age', 'number_of_dependants', 'income_lakhs', 'total_risk_score']

# 2. Category hierarchies
plan_order = ['Bronze', 'Silver', 'Gold']
income_order = ['<10L', '10L - 25L', '25L - 40L', '> 40L']

# 3. Pipelines to encode strings first, then scale numeric outputs
plan_pipeline = Pipeline([
    ('encoder', OrdinalEncoder(categories=[plan_order])),
    ('scaler', MinMaxScaler())
])

income_pipeline = Pipeline([
    ('encoder', OrdinalEncoder(categories=[income_order])),
    ('scaler', MinMaxScaler())
])

# 4. ColumnTransformer setup
preprocessor = ColumnTransformer(
    transformers=[
        ('nominal', OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'), nominal_cols),
        ('plan_pipeline', plan_pipeline, ['insurance_plan']),
        ('income_pipeline', income_pipeline, ['income_level']),
        ('numeric_scaler', MinMaxScaler(), numeric_cols)  # Passed directly without extra brackets
    ],
    remainder='passthrough',
    verbose_feature_names_out=False
)

preprocessor.set_output(transform='pandas')

X_train_processed = preprocessor.fit_transform(X_train)

# %%
X_train_processed.head()
# Out:
#        gender_Male  region_Northwest  region_Southeast  region_Southwest  \
# 3829           0.0               0.0               0.0               1.0
# 15499          0.0               1.0               0.0               0.0
# 6306           1.0               0.0               0.0               0.0
# 14010          1.0               0.0               1.0               0.0
# 13819          0.0               0.0               1.0               0.0
#
#        marital_status_Unmarried  bmi_category_Obesity  \
# 3829                        1.0                   0.0
# 15499                       1.0                   0.0
# 6306                        1.0                   0.0
# 14010                       1.0                   0.0
# 13819                       1.0                   1.0
#
#        bmi_category_Overweight  bmi_category_Underweight  \
# 3829                       0.0                       0.0
# 15499                      0.0                       0.0
# 6306                       1.0                       0.0
# 14010                      1.0                       0.0
# 13819                      0.0                       0.0
#
#        smoking_status_Occasional  smoking_status_Regular  \
# 3829                         0.0                     0.0
# 15499                        0.0                     0.0
# 6306                         0.0                     1.0
# 14010                        1.0                     0.0
# 13819                        0.0                     0.0
#
#        employment_status_Salaried  employment_status_Self-Employed  \
# 3829                          0.0                              0.0
# 15499                         0.0                              0.0
# 6306                          0.0                              0.0
# 14010                         0.0                              1.0
# 13819                         1.0                              0.0
#
#        insurance_plan  income_level       age  number_of_dependants  \
# 3829              0.5      0.666667  0.428571              0.000000
# 15499             0.0      0.000000  0.428571              1.000000
# 6306              0.0      0.666667  0.857143              0.000000
# 14010             0.0      0.000000  0.571429              0.333333
# 13819             0.0      0.000000  0.571429              0.000000
#
#        income_lakhs  total_risk_score  genetical_risk
# 3829       0.292929               0.0               4
# 15499      0.010101               0.0               1
# 6306       0.363636               0.0               2
# 14010      0.050505               0.0               0
# 13819      0.050505               0.0               3

# %%
X_test_processed = preprocessor.transform(X_test)
X_test_processed
# Out:
#        gender_Male  region_Northwest  region_Southeast  region_Southwest  \
# 10489          1.0               0.0               0.0               0.0
# 7989           1.0               0.0               0.0               1.0
# 3113           1.0               0.0               0.0               1.0
# 10605          1.0               0.0               1.0               0.0
# 4204           0.0               0.0               1.0               0.0
# ...            ...               ...               ...               ...
# 18960          0.0               0.0               0.0               1.0
# 266            1.0               0.0               1.0               0.0
# 10036          1.0               0.0               1.0               0.0
# 15506          1.0               1.0               0.0               0.0
# 10890          1.0               0.0               1.0               0.0
#
#        marital_status_Unmarried  bmi_category_Obesity  \
# 10489                       0.0                   0.0
# 7989                        1.0                   0.0
# 3113                        1.0                   0.0
# 10605                       1.0                   0.0
# 4204                        1.0                   0.0
# ...                         ...                   ...
# 18960                       1.0                   0.0
# 266                         1.0                   0.0
# 10036                       1.0                   0.0
# 15506                       0.0                   0.0
# 10890                       1.0                   0.0
#
#        bmi_category_Overweight  bmi_category_Underweight  \
# 10489                      0.0                       0.0
# 7989                       0.0                       0.0
# 3113                       0.0                       0.0
# 10605                      1.0                       0.0
# 4204                       0.0                       1.0
# ...                        ...                       ...
# 18960                      0.0                       0.0
# 266                        0.0                       0.0
# 10036                      0.0                       0.0
# 15506                      0.0                       1.0
# 10890                      1.0                       0.0
#
#        smoking_status_Occasional  smoking_status_Regular  \
# 10489                        0.0                     0.0
# 7989                         0.0                     0.0
# 3113                         0.0                     1.0
# 10605                        0.0                     0.0
# 4204                         0.0                     1.0
# ...                          ...                     ...
# 18960                        0.0                     0.0
# 266                          0.0                     0.0
# 10036                        0.0                     0.0
# 15506                        0.0                     0.0
# 10890                        0.0                     0.0
#
#        employment_status_Salaried  employment_status_Self-Employed  \
# 10489                         0.0                              0.0
# 7989                          0.0                              0.0
# 3113                          1.0                              0.0
# 10605                         0.0                              0.0
# 4204                          0.0                              0.0
# ...                           ...                              ...
# 18960                         0.0                              0.0
# 266                           0.0                              0.0
# 10036                         0.0                              0.0
# 15506                         0.0                              0.0
# 10890                         0.0                              0.0
#
#        insurance_plan  income_level       age  number_of_dependants  \
# 10489             0.0      0.000000  0.428571              1.000000
# 7989              0.0      0.000000  0.714286              0.000000
# 3113              0.0      0.666667  0.142857              0.000000
# 10605             0.5      1.000000  0.428571              0.000000
# 4204              0.0      0.333333  0.000000              0.000000
# ...               ...           ...       ...                   ...
# 18960             0.0      0.333333  0.428571              0.333333
# 266               1.0      0.000000  0.857143              0.333333
# 10036             0.5      0.000000  0.857143              0.000000
# 15506             1.0      1.000000  0.571429              1.000000
# 10890             0.0      0.000000  0.428571              0.000000
#
#        income_lakhs  total_risk_score  genetical_risk
# 10489      0.080808          0.428571               1
# 7989       0.030303          1.000000               4
# 3113       0.363636          1.000000               0
# 10605      0.515152          0.428571               4
# 4204       0.222222          0.000000               0
# ...             ...               ...             ...
# 18960      0.181818          0.000000               0
# 266        0.000000          0.000000               1
# 10036      0.060606          0.000000               4
# 15506      0.686869          0.357143               2
# 10890      0.050505          0.000000               4
#
# [6026 rows x 19 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X_train_processed)
# Out:
#                              Column        VIF
# 0                       gender_Male   2.307954
# 1                  region_Northwest   2.176789
# 2                  region_Southeast   2.963829
# 3                  region_Southwest   2.740467
# 4          marital_status_Unmarried   8.044267
# 5              bmi_category_Obesity   1.115150
# 6           bmi_category_Overweight   1.231103
# 7          bmi_category_Underweight   1.373569
# 8         smoking_status_Occasional   1.133403
# 9            smoking_status_Regular   1.387821
# 10       employment_status_Salaried   1.674361
# 11  employment_status_Self-Employed   1.302132
# 12                   insurance_plan   1.597377
# 13                     income_level  11.978140
# 14                              age   3.187482
# 15             number_of_dependants   1.938552
# 16                     income_lakhs  11.951075
# 17                 total_risk_score   1.153875
# 18                   genetical_risk   2.993974

# %%
X_train_processed_final = X_train_processed.drop(columns=['income_level'])
X_train_processed_final.columns
# Out:
# Index(['gender_Male', 'region_Northwest', 'region_Southeast',
#        'region_Southwest', 'marital_status_Unmarried', 'bmi_category_Obesity',
#        'bmi_category_Overweight', 'bmi_category_Underweight',
#        'smoking_status_Occasional', 'smoking_status_Regular',
#        'employment_status_Salaried', 'employment_status_Self-Employed',
#        'insurance_plan', 'age', 'number_of_dependants', 'income_lakhs',
#        'total_risk_score', 'genetical_risk'],
#       dtype='str')

# %%
X_test_processed = X_test_processed.drop(columns=['income_level'])

# %% [markdown]
# <h2 align="center" style="color:green">Model Training</h2>

# %% [markdown]
# ### LinearRegression

# %%
model_lr = LinearRegression()
model_lr.fit(X_train_processed_final, y_train)

test_score = model_lr.score(X_test_processed, y_test)
train_score = model_lr.score(X_train_processed_final, y_train)
print(train_score, test_score)

y_pred = model_lr.predict(X_test_processed)
mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)

mse_lr, rmse_lr
# Out:
# 0.9884990017445308 0.9882609305654483
# (89439.73145260854, np.float64(299.0647613019771))

# %%
model_lr.coef_
# Out:
# array([ 6.08209851e+00,  1.91642829e+00,  2.07974087e+00,  8.29849020e+00,
#         1.42155309e+01,  8.01977884e+02,  4.04437286e+02,  1.13743592e+02,
#         2.07656492e+02,  6.07368444e+02,  7.08985789e+00,  9.30425482e+00,
#         6.99564576e+03, -1.05801891e-01,  2.01069306e+01, -1.18192939e+01,
#         1.13118985e+03,  9.96735067e+02])

# %%
feature_importance = model_lr.coef_

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_processed_final.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Linear Regression')
plt.show()

# %%
from sklearn.linear_model import Ridge

model_reg = Ridge(alpha=1)

model_reg.fit(X_train_processed_final, y_train)

test_score = model_reg.score(X_test_processed, y_test)
train_score = model_reg.score(X_train_processed_final, y_train)
print(train_score, test_score)

y_pred = model_reg.predict(X_test_processed)
mse_reg = mean_squared_error(y_test, y_pred)
rmse_reg = np.sqrt(mse_lr)

mse_reg, rmse_reg
# Out:
# 0.9884985406626117 0.9882597413296531
# (89448.79221596352, np.float64(299.0647613019771))

# %%
from xgboost import XGBRegressor

model_xgb = XGBRegressor(n_estimators=20, max_depth=3)

model_xgb.fit(X_train_processed_final, y_train)

model_xgb.fit(X_train_processed_final, y_train)
model_xgb.score(X_test_processed, y_test)
# Out:
# 0.9872627258300781

# %%
y_pred = model_xgb.predict(X_test_processed)

mse_xgb = mean_squared_error(y_test, y_pred)
rmse_xgb = np.sqrt(mse_xgb)

mse_xgb, rmse_xgb
# Out:
# (97045.09375, np.float64(311.5206152889404))

# %%
model_xgb = XGBRegressor()

param_grid = {
    'n_estimators': [20, 40, 50],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
}

random_search = RandomizedSearchCV(model_xgb, param_grid, n_iter=10, cv=3, scoring='r2', random_state=42, n_jobs=-1)
random_search.fit(X_train_processed_final, y_train)
random_search.best_score_
# Out:
# np.float64(0.9881292382876078)

# %%
random_search.best_params_
# Out:
# {'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.1}

# %%
best_model = random_search.best_estimator_

# %%
feature_importance = best_model.feature_importances_

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_processed_final.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in XGBoost')
plt.show()

# %%
y_pred = best_model.predict(X_test_processed)

residuals = y_pred - y_test
residuals_pct = (residuals / y_test) * 100

results_df = pd.DataFrame({
    'actual': y_test, 
    'predicted': y_pred, 
    'diff': residuals, 
    'diff_pct': residuals_pct
})
results_df.head()
# Out:
#        actual     predicted        diff   diff_pct
# 10489    5452   5459.750000    7.750000   0.142150
# 7989     9658   9034.060547 -623.939453  -6.460338
# 3113     6031   5777.926270 -253.073730  -4.196215
# 10605   12386  12143.197266 -242.802734  -1.960300
# 4204     4245   4701.327637  456.327637  10.749768

# %%
sns.histplot(results_df['diff_pct'], kde=True)
plt.title('Distribution of Residuals')
plt.xlabel('Diff PCT')
plt.ylabel('Frequency')
plt.show()

# %%
X_test_processed.shape
# Out:
# (6026, 18)

# %%
extreme_error_threshold = 10  # You can adjust this threshold based on your domain knowledge or requirements
extreme_results_df = results_df[np.abs(results_df['diff_pct']) > extreme_error_threshold]
extreme_results_df.head()
# Out:
#        actual    predicted        diff   diff_pct
# 4204     4245  4701.327637  456.327637  10.749768
# 8862     4206  4635.344238  429.344238  10.207899
# 3396     4568  5068.031250  500.031250  10.946393
# 13142    4215  4704.776855  489.776855  11.619854
# 7802     4096  4538.517090  442.517090  10.803640

# %%
extreme_results_df.shape
# Out:
# (155, 4)

# %%
extreme_errors_pct = extreme_results_df.shape[0]*100/X_test.shape[0]
extreme_errors_pct
# Out:
# 2.572187188848324

# %% [markdown]
# We have 2% extreme errors which means for 2% customers we will either overcharge or undercharge by 10% or more

# %%
extreme_results_df[abs(extreme_results_df.diff_pct)>50].sort_values("diff_pct",ascending=False)
# Out:
# Empty DataFrame
# Columns: [actual, predicted, diff, diff_pct]
# Index: []

# %% [markdown]
# There will be about 0 customers whom we will overcharge or underchage by more than 50%

# %%
extreme_errors_df = X_test_processed.loc[extreme_results_df.index]
extreme_errors_df.head(2)
# Out:
#       gender_Male  region_Northwest  region_Southeast  region_Southwest  \
# 4204          0.0               0.0               1.0               0.0
# 8862          1.0               0.0               0.0               0.0
#
#       marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# 4204                       1.0                   0.0                      0.0
# 8862                       1.0                   0.0                      0.0
#
#       bmi_category_Underweight  smoking_status_Occasional  \
# 4204                       1.0                        0.0
# 8862                       0.0                        0.0
#
#       smoking_status_Regular  employment_status_Salaried  \
# 4204                     1.0                         0.0
# 8862                     1.0                         1.0
#
#       employment_status_Self-Employed  insurance_plan       age  \
# 4204                              0.0             0.0  0.000000
# 8862                              0.0             0.0  0.714286
#
#       number_of_dependants  income_lakhs  total_risk_score  genetical_risk
# 4204              0.000000      0.222222               0.0               0
# 8862              0.333333      0.010101               0.0               0

# %%
for feature in X_test_processed.columns:
    plt.figure(figsize=(10, 4))
    sns.histplot(extreme_errors_df[feature], color='red', label='Extreme Errors', kde=True)
    sns.histplot(X_test_processed[feature], color='blue', label='Overall', alpha=0.5, kde=True)
    plt.legend()
    plt.title(f'Distribution of {feature} for Extreme Errors vs Overall')
    plt.show()

# %%
extreme_errors_df['income_level']=-1

# %%
# Create a copy so you keep the rest of the columns intact
df_reversed = extreme_errors_df.copy()

# 1. Retrieve the fitted scaler from the ColumnTransformer
scaler = preprocessor.named_transformers_['numeric_scaler']

# 2. Inverse-transform only the numeric columns
df_reversed[numeric_cols] = scaler.inverse_transform(extreme_errors_df[numeric_cols])

df_reversed.head()
# Out:
#        gender_Male  region_Northwest  region_Southeast  region_Southwest  \
# 4204           0.0               0.0               1.0               0.0
# 8862           1.0               0.0               0.0               0.0
# 3396           1.0               1.0               0.0               0.0
# 13142          0.0               0.0               0.0               1.0
# 7802           1.0               0.0               1.0               0.0
#
#        marital_status_Unmarried  bmi_category_Obesity  \
# 4204                        1.0                   0.0
# 8862                        1.0                   0.0
# 3396                        1.0                   0.0
# 13142                       0.0                   0.0
# 7802                        0.0                   0.0
#
#        bmi_category_Overweight  bmi_category_Underweight  \
# 4204                       0.0                       1.0
# 8862                       0.0                       0.0
# 3396                       0.0                       0.0
# 13142                      0.0                       0.0
# 7802                       0.0                       1.0
#
#        smoking_status_Occasional  smoking_status_Regular  \
# 4204                         0.0                     1.0
# 8862                         0.0                     1.0
# 3396                         0.0                     0.0
# 13142                        1.0                     0.0
# 7802                         0.0                     0.0
#
#        employment_status_Salaried  employment_status_Self-Employed  \
# 4204                          0.0                              0.0
# 8862                          1.0                              0.0
# 3396                          0.0                              0.0
# 13142                         1.0                              0.0
# 7802                          0.0                              0.0
#
#        insurance_plan   age  number_of_dependants  income_lakhs  \
# 4204              0.0  18.0                   0.0          23.0
# 8862              0.0  23.0                   1.0           2.0
# 3396              0.0  25.0                   0.0           3.0
# 13142             0.0  22.0                   2.0           8.0
# 7802              0.0  24.0                   3.0           3.0
#
#        total_risk_score  genetical_risk  income_level
# 4204                0.0               0            -1
# 8862                0.0               0            -1
# 3396                0.0               1            -1
# 13142               6.0               0            -1
# 7802                5.0               0            -1

# %%
sns.histplot(df_reversed.age)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
import os
from joblib import dump

# Ensure folder exists
os.makedirs("models", exist_ok=True)

# Save the preprocessor (handles all encoding + scaling + column tracking)
dump(preprocessor, "models/preprocessor_young.joblib")

# Save the trained model
dump(best_model, "models/model_young.joblib")
# Out:
# ['models/model_young.joblib']
